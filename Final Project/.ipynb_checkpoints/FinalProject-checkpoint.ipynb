# %% [markdown]
# # CMPINF0010 Lab Final Project

# %% [markdown]
# ## __Team Money__ (This is just a placeholder till we find a good name lol)

# %% [markdown]
# ## The Metric
#
# We determined, after very careful consideration, that in order to quantify the best nieghborhood, there was really only one possible metric that would do this. And so, we decided to determine the best neighborhood in Pittsburgh based off of the metric of which neighborhood was the most expensive.
#
# The reasons for this metric are very simple, for as we all know that if you live in a rich neighborhood, you will become rich by proxxy. We want this, especially because the relationship between happiness and monetary wealth is 1:1.
#
# In order to determine which neighborhood was the most expensive, we looked at four different measurements of this: **Contract Rent**, **Mortgage Status**, **Housing Unit Value**, and **Wage/Salary Income**.

# %% [markdown]
# ## The Data
#
# First, let's begin by setting up our needed libraries

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Contract Rent
#
# This is the measurement which describes the mean price to pay monthly for renting a house/apartment. Of course, we want to go where the people are paying the most, so we are going to be looking for the neighborhood with the *Highest Mean Price*.
#
# We need to first get our data.

# %%
rents = pd.read_csv("contract-rent.csv", index_col ="Neighborhood")
rents.head(10)
# Out:
#                    Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center    1             798.0                91.000000
# Allegheny West      2              77.0                31.000000
# Allentown           3             531.0               138.166566
# Arlington           4             209.0                70.562029
# Arlington Heights   5             144.0                59.000000
# Banksville          6             961.0               190.089453
# Bedford Dwellings   7             675.0                56.000000
# Beechview           8            1502.0               236.021185
# Beltzhoover         9             292.0               111.772090
# Bloomfield         10            2883.0               201.732496
#
#                    Estimate; With cash rent:  \
# Neighborhood
# Allegheny Center                       781.0
# Allegheny West                          77.0
# Allentown                              481.0
# Arlington                              204.0
# Arlington Heights                      140.0
# Banksville                             961.0
# Bedford Dwellings                      668.0
# Beechview                             1464.0
# Beltzhoover                            287.0
# Bloomfield                            2825.0
#
#                    Margin of Error; With cash rent:  \
# Neighborhood
# Allegheny Center                          89.000000
# Allegheny West                            31.000000
# Allentown                                120.540450
# Arlington                                 69.899928
# Arlington Heights                         59.000000
# Banksville                               190.089453
# Bedford Dwellings                         57.000000
# Beechview                                234.068366
# Beltzhoover                              111.772090
# Bloomfield                               200.808366
#
#                    Estimate; With cash rent: - Less than $100  \
# Neighborhood
# Allegheny Center                                         23.0
# Allegheny West                                            0.0
# Allentown                                                 0.0
# Arlington                                                 0.0
# Arlington Heights                                         0.0
# Banksville                                                0.0
# Bedford Dwellings                                       216.0
# Beechview                                                 0.0
# Beltzhoover                                               0.0
# Bloomfield                                                0.0
#
#                    Margin of Error; With cash rent: - Less than $100  \
# Neighborhood
# Allegheny Center                                           27.000000
# Allegheny West                                             10.000000
# Allentown                                                  17.320508
# Arlington                                                  17.320508
# Arlington Heights                                          10.000000
# Banksville                                                 20.000000
# Bedford Dwellings                                          72.000000
# Beechview                                                  31.622777
# Beltzhoover                                                20.000000
# Bloomfield                                                 31.622777
#
#                    Estimate; With cash rent: - $100 to $149  \
# Neighborhood
# Allegheny Center                                        6.0
# Allegheny West                                          0.0
# Allentown                                               0.0
# Arlington                                               0.0
# Arlington Heights                                       6.0
# Banksville                                              0.0
# Bedford Dwellings                                      20.0
# Beechview                                               0.0
# Beltzhoover                                            10.0
# Bloomfield                                              6.0
#
#                    Margin of Error; With cash rent: - $100 to $149  \
# Neighborhood
# Allegheny Center                                          8.000000
# Allegheny West                                           10.000000
# Allentown                                                17.320508
# Arlington                                                17.320508
# Arlington Heights                                         8.000000
# Banksville                                               20.000000
# Bedford Dwellings                                        19.000000
# Beechview                                                31.622777
# Beltzhoover                                              22.912878
# Bloomfield                                               31.320920
#
#                    Estimate; With cash rent: - $150 to $199  ...  \
# Neighborhood                                                 ...
# Allegheny Center                                       77.0  ...
# Allegheny West                                          0.0  ...
# Allentown                                              18.0  ...
# Arlington                                               0.0  ...
# Arlington Heights                                      23.0  ...
# Banksville                                              0.0  ...
# Bedford Dwellings                                      37.0  ...
# Beechview                                               0.0  ...
# Beltzhoover                                             0.0  ...
# Bloomfield                                              7.0  ...
#
#                    Estimate; With cash rent: - $2,000 to $2,499  \
# Neighborhood
# Allegheny Center                                            0.0
# Allegheny West                                              0.0
# Allentown                                                   0.0
# Arlington                                                   0.0
# Arlington Heights                                           0.0
# Banksville                                                  0.0
# Bedford Dwellings                                           0.0
# Beechview                                                   0.0
# Beltzhoover                                                 0.0
# Bloomfield                                                 17.0
#
#                    Margin of Error; With cash rent: - $2,000 to $2,499  \
# Neighborhood
# Allegheny Center                                           10.000000
# Allegheny West                                             10.000000
# Allentown                                                  17.320508
# Arlington                                                  17.320508
# Arlington Heights                                          10.000000
# Banksville                                                 20.000000
# Bedford Dwellings                                          10.000000
# Beechview                                                  31.622777
# Beltzhoover                                                20.000000
# Bloomfield                                                 33.541020
#
#                    Estimate; With cash rent: - $2,500 to $2,999  \
# Neighborhood
# Allegheny Center                                            0.0
# Allegheny West                                              0.0
# Allentown                                                   0.0
# Arlington                                                   0.0
# Arlington Heights                                           0.0
# Banksville                                                  0.0
# Bedford Dwellings                                           0.0
# Beechview                                                   0.0
# Beltzhoover                                                 0.0
# Bloomfield                                                  0.0
#
#                    Margin of Error; With cash rent: - $2,500 to $2,999  \
# Neighborhood
# Allegheny Center                                           10.000000
# Allegheny West                                             10.000000
# Allentown                                                  17.320508
# Arlington                                                  17.320508
# Arlington Heights                                          10.000000
# Banksville                                                 20.000000
# Bedford Dwellings                                          10.000000
# Beechview                                                  31.622777
# Beltzhoover                                                20.000000
# Bloomfield                                                 31.622777
#
#                    Estimate; With cash rent: - $3,000 to $3,499  \
# Neighborhood
# Allegheny Center                                            0.0
# Allegheny West                                              0.0
# Allentown                                                   0.0
# Arlington                                                   0.0
# Arlington Heights                                           0.0
# Banksville                                                  0.0
# Bedford Dwellings                                           0.0
# Beechview                                                   0.0
# Beltzhoover                                                 0.0
# Bloomfield                                                  0.0
#
#                    Margin of Error; With cash rent: - $3,000 to $3,499  \
# Neighborhood
# Allegheny Center                                           10.000000
# Allegheny West                                             10.000000
# Allentown                                                  17.320508
# Arlington                                                  17.320508
# Arlington Heights                                          10.000000
# Banksville                                                 20.000000
# Bedford Dwellings                                          10.000000
# Beechview                                                  31.622777
# Beltzhoover                                                20.000000
# Bloomfield                                                 31.622777
#
#                    Estimate; With cash rent: - $3,500 or more  \
# Neighborhood
# Allegheny Center                                          0.0
# Allegheny West                                            0.0
# Allentown                                                 0.0
# Arlington                                                 0.0
# Arlington Heights                                         0.0
# Banksville                                                0.0
# Bedford Dwellings                                         0.0
# Beechview                                                 0.0
# Beltzhoover                                               0.0
# Bloomfield                                                0.0
#
#                    Margin of Error; With cash rent: - $3,500 or more  \
# Neighborhood
# Allegheny Center                                           10.000000
# Allegheny West                                             10.000000
# Allentown                                                  17.320508
# Arlington                                                  17.320508
# Arlington Heights                                          10.000000
# Banksville                                                 20.000000
# Bedford Dwellings                                          10.000000
# Beechview                                                  31.622777
# Beltzhoover                                                20.000000
# Bloomfield                                                 31.622777
#
#                    Estimate; No cash rent  Margin of Error; No cash rent
# Neighborhood
# Allegheny Center                     17.0                      12.000000
# Allegheny West                        0.0                      10.000000
# Allentown                            50.0                      78.287930
# Arlington                             5.0                      15.779734
# Arlington Heights                     4.0                       6.000000
# Banksville                            0.0                      20.000000
# Bedford Dwellings                     7.0                      10.000000
# Beechview                            38.0                      39.370039
# Beltzhoover                           5.0                      19.519221
# Bloomfield                           58.0                      36.318040
#
# [10 rows x 55 columns]

# %% [markdown]
# The way our data is set up, we have counts of which neighborhoods have a certain value of rent. For example, we can see here that Allgeheny Center has 77 people in this set that have rent from 150 to 199 dollars.
#
# In order to find the average rent for each neighborhood, we can divide the total rent each sample group in this dataset pays and divide it by the sample size.
#
# In order to do this, we can first start by making a dictionary which stores the column name along with the mean price in the price range. This is the number that we'll use in our calculations, as there is no data to indicate whether the rent falls in the low or high ends of the range.

# %%
value_dict = {
    "Less than $100" : 100,
    "$100 to $149" : 125,
    "$150 to $199" : 175,
    "$200 to $249" : 225,
    "$250 to $299" : 275,
    "$300 to $349" : 325,
    "$350 to $399" : 375,
    "$400 to $449" : 425,
    "$450 to $499" : 475,
    "$500 to $549" : 525,
    "$550 to $599" : 575,
    "$600 to $649" : 625,
    "$650 to $699" : 675,
    "$700 to $749" : 725,
    "$750 to $799" : 775,
    "$800 to $899" : 850,
    "$900 to $999" : 950,
    "$1,000 to $1,249" : 1125,
    "$1,250 to $1,499" : 1375,
    "$1,500 to $1,999" : 1750,
    "$2,000 to $2,499" : 2250,
    "$2,500 to $2,999" : 2750,
    "$3,000 to $3,499" : 3250,
    "$3,500 or more" : 3500,
}

# %% [markdown]
# Next, we can use this dictionary to add up all of the rents for each column, and then divide it by the people polled.
# For places with no sample group, we will just have them set as paying 0 rent, which will exclude them from this measurement.

# %%
total_avgs = []
for index, row in rents.iterrows():
    total_rent = 0
    for key in value_dict.keys():
        total_rent += row["Estimate; With cash rent: - " + key] * value_dict[key]
        total_houses = row['Estimate; Total:']

    if total_houses == 0:
        total_avgs.append(0)
    else:
        total_avgs.append(float((total_rent))/total_houses)

neighborhoods = rents.index
average_rents = pd.DataFrame({"Neighborhood": neighborhoods, "Average Rent": total_avgs})
average_rents = average_rents.set_index("Neighborhood")
average_rents = average_rents.sort_values(by="Average Rent", ascending = False)
average_rents.head()
# Out:
#                            Average Rent
# Neighborhood
# Strip District              1675.111607
# North Shore                 1400.487013
# Central Business District   1333.672820
# Ridgemont                   1276.923077
# Squirrel Hill North         1176.389879

# %% [markdown]
# Now, we can just graph this new dataset.

# %%
average_rents.plot(kind="bar", stacked = True, ylim = 0, figsize = (20, 4), title = "Average Rent By Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Unit Value")
plt.legend("", frameon=False)
plt.show()

# %% [markdown]
# From this data, we can see that the Strip District has the most expensive average rent out of any neighborhood, coming in at an average of $1675 a month. And, as such, this is the best place to live in Pittsburgh (For this metric).

# %% [markdown]
# ### Housing Unit Value

# %% [markdown]
# This is the measurement of the average value of each house in a nieghborhood.
#
# First, let's print out the data set to see what we are working with.

# %%
housing_unit = pd.read_csv("unit-value.csv", index_col ="Neighborhood")
housing_unit.head(len(housing_unit.index))
# Out:
#                      Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center      1              72.0                28.000000
# Allegheny West        2              69.0                31.000000
# Allentown             3             538.0               112.769677
# Arlington             4             492.0                84.433406
# Arlington Heights     5               0.0                10.000000
# ...                  ..               ...                      ...
# Upper Lawrenceville  87             594.0               115.952577
# West End             88              35.0                23.000000
# West Oakland         89             204.0                51.855569
# Westwood             90             973.0               102.552426
# Windgap              91             537.0                87.458562
#
#                      Estimate; Total: - Less than $10,000  \
# Neighborhood
# Allegheny Center                                      0.0
# Allegheny West                                        4.0
# Allentown                                            45.0
# Arlington                                            12.0
# Arlington Heights                                     0.0
# ...                                                   ...
# Upper Lawrenceville                                   0.0
# West End                                              0.0
# West Oakland                                          0.0
# Westwood                                             29.0
# Windgap                                              25.0
#
#                      Margin of Error; Total: - Less than $10,000  \
# Neighborhood
# Allegheny Center                                       10.000000
# Allegheny West                                          7.000000
# Allentown                                              33.734256
# Arlington                                              16.186414
# Arlington Heights                                      10.000000
# ...                                                          ...
# Upper Lawrenceville                                    17.320508
# West End                                               10.000000
# West Oakland                                           14.142136
# Westwood                                               25.495098
# Windgap                                                21.470911
#
#                      Estimate; Total: - $10,000 to $14,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                             19.0
# Arlington                                             29.0
# Arlington Heights                                      0.0
# ...                                                    ...
# Upper Lawrenceville                                    0.0
# West End                                               0.0
# West Oakland                                           0.0
# Westwood                                               0.0
# Windgap                                               36.0
#
#                      Margin of Error; Total: - $10,000 to $14,999  \
# Neighborhood
# Allegheny Center                                        10.000000
# Allegheny West                                          10.000000
# Allentown                                               21.118712
# Arlington                                               27.513633
# Arlington Heights                                       10.000000
# ...                                                           ...
# Upper Lawrenceville                                     17.320508
# West End                                                10.000000
# West Oakland                                            14.142136
# Westwood                                                14.142136
# Windgap                                                 39.293765
#
#                      Estimate; Total: - $15,000 to $19,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                             22.0
# Arlington                                              5.0
# Arlington Heights                                      0.0
# ...                                                    ...
# Upper Lawrenceville                                   17.0
# West End                                               0.0
# West Oakland                                          10.0
# Westwood                                               0.0
# Windgap                                                5.0
#
#                      Margin of Error; Total: - $15,000 to $19,999  \
# Neighborhood
# Allegheny Center                                        10.000000
# Allegheny West                                          10.000000
# Allentown                                               26.153394
# Arlington                                               16.248077
# Arlington Heights                                       10.000000
# ...                                                           ...
# Upper Lawrenceville                                     27.856777
# West End                                                10.000000
# West Oakland                                            16.401219
# Westwood                                                14.142136
# Windgap                                                 12.806248
#
#                      Estimate; Total: - $20,000 to $24,999  ...  \
# Neighborhood                                                ...
# Allegheny Center                                       0.0  ...
# Allegheny West                                         0.0  ...
# Allentown                                             44.0  ...
# Arlington                                             43.0  ...
# Arlington Heights                                      0.0  ...
# ...                                                    ...  ...
# Upper Lawrenceville                                   13.0  ...
# West End                                              12.0  ...
# West Oakland                                           0.0  ...
# Westwood                                               0.0  ...
# Windgap                                                0.0  ...
#
#                      Estimate; Total: - $500,000 to $749,999  \
# Neighborhood
# Allegheny Center                                         0.0
# Allegheny West                                           0.0
# Allentown                                                6.0
# Arlington                                                7.0
# Arlington Heights                                        0.0
# ...                                                      ...
# Upper Lawrenceville                                      0.0
# West End                                                 0.0
# West Oakland                                             0.0
# Westwood                                                 0.0
# Windgap                                                  0.0
#
#                      Margin of Error; Total: - $500,000 to $749,999  \
# Neighborhood
# Allegheny Center                                          10.000000
# Allegheny West                                            10.000000
# Allentown                                                 16.763055
# Arlington                                                 17.916473
# Arlington Heights                                         10.000000
# ...                                                             ...
# Upper Lawrenceville                                       17.320508
# West End                                                  10.000000
# West Oakland                                              14.142136
# Westwood                                                  14.142136
# Windgap                                                   14.142136
#
#                      Estimate; Total: - $750,000 to $999,999  \
# Neighborhood
# Allegheny Center                                         0.0
# Allegheny West                                           0.0
# Allentown                                                0.0
# Arlington                                                0.0
# Arlington Heights                                        0.0
# ...                                                      ...
# Upper Lawrenceville                                      0.0
# West End                                                 0.0
# West Oakland                                             0.0
# Westwood                                                 0.0
# Windgap                                                  0.0
#
#                      Margin of Error; Total: - $750,000 to $999,999  \
# Neighborhood
# Allegheny Center                                          10.000000
# Allegheny West                                            10.000000
# Allentown                                                 17.320508
# Arlington                                                 17.320508
# Arlington Heights                                         10.000000
# ...                                                             ...
# Upper Lawrenceville                                       17.320508
# West End                                                  10.000000
# West Oakland                                              14.142136
# Westwood                                                  14.142136
# Windgap                                                   14.142136
#
#                      Estimate; Total: - $1,000,000 to $1,499,999  \
# Neighborhood
# Allegheny Center                                             0.0
# Allegheny West                                              11.0
# Allentown                                                    0.0
# Arlington                                                    3.0
# Arlington Heights                                            0.0
# ...                                                          ...
# Upper Lawrenceville                                          0.0
# West End                                                     0.0
# West Oakland                                                 0.0
# Westwood                                                     0.0
# Windgap                                                      0.0
#
#                      Margin of Error; Total: - $1,000,000 to $1,499,999  \
# Neighborhood
# Allegheny Center                                             10.000000
# Allegheny West                                               17.000000
# Allentown                                                    17.320508
# Arlington                                                    15.779734
# Arlington Heights                                            10.000000
# ...                                                                ...
# Upper Lawrenceville                                          17.320508
# West End                                                     10.000000
# West Oakland                                                 14.142136
# Westwood                                                     14.142136
# Windgap                                                      14.142136
#
#                      Estimate; Total: - $1,500,000 to $1,999,999  \
# Neighborhood
# Allegheny Center                                             0.0
# Allegheny West                                               0.0
# Allentown                                                    0.0
# Arlington                                                    0.0
# Arlington Heights                                            0.0
# ...                                                          ...
# Upper Lawrenceville                                          0.0
# West End                                                     0.0
# West Oakland                                                 0.0
# Westwood                                                     0.0
# Windgap                                                      0.0
#
#                      Margin of Error; Total: - $1,500,000 to $1,999,999  \
# Neighborhood
# Allegheny Center                                             10.000000
# Allegheny West                                               10.000000
# Allentown                                                    17.320508
# Arlington                                                    17.320508
# Arlington Heights                                            10.000000
# ...                                                                ...
# Upper Lawrenceville                                          17.320508
# West End                                                     10.000000
# West Oakland                                                 14.142136
# Westwood                                                     14.142136
# Windgap                                                      14.142136
#
#                      Estimate; Total: - $2,000,000 or more  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
# ...                                                    ...
# Upper Lawrenceville                                    0.0
# West End                                               0.0
# West Oakland                                           0.0
# Westwood                                               0.0
# Windgap                                                0.0
#
#                      Margin of Error; Total: - $2,000,000 or more
# Neighborhood
# Allegheny Center                                        10.000000
# Allegheny West                                          10.000000
# Allentown                                               17.320508
# Arlington                                               17.320508
# Arlington Heights                                       10.000000
# ...                                                           ...
# Upper Lawrenceville                                     17.320508
# West End                                                10.000000
# West Oakland                                            14.142136
# Westwood                                                14.142136
# Windgap                                                 14.142136
#
# [91 rows x 55 columns]

# %% [markdown]
# That's a lot of information, however it is quite simple once you look at it all. We've 26 price ranges that housing units call fall under. In order to find which neighborhood has the most expensive housing units on average, we can add every price range multiplied by the number of units listed under it for each neighborhood and divide it by the total number of units within the neighborhood.
# For ease of viewing, we'll create two new colums in our data set, one showing the sum of the cost of every unit in the neighborhood, and one for the average of each neighborhood.
#
# We can also rename the columns to be referenced in our calculations, setting them to the average of the starting and endpoints.
#
# For our purposes, we'll ignore the margin of error metric.

# %%
value_dict = {
    "Less than $10,000" : 10000,
    "$10,000 to $14,999" : 125000,
    "$15,000 to $19,999" : 17500,
    "$20,000 to $24,999" : 22500,
    "$25,000 to $29,999" : 27500,
    "$30,000 to $34,999" : 32500,
    "$35,000 to $39,999" : 37500,
    "$40,000 to $49,999" : 45000,
    "$50,000 to $59,999" : 55000,
    "$60,000 to $69,999" : 65000,
    "$70,000 to $79,999" : 75000,
    "$80,000 to $89,999" : 85000,
    "$90,000 to $99,999" : 95000,
    "$100,000 to $124,999" : 112500,
    "$125,000 to $149,999" : 137500,
    "$150,000 to $174,999" : 162500,
    "$175,000 to $199,999" : 187500,
    "$200,000 to $249,999" : 225000,
    "$250,000 to $299,999" : 275000,
    "$300,000 to $399,999" : 350000,
    "$400,000 to $499,999" : 450000,
    "$500,000 to $749,999" : 625000,
    "$750,000 to $999,999" : 875000,
    "$1,000,000 to $1,499,999" : 1250000,
    "$1,500,000 to $1,999,999" : 1750000,
    "$2,000,000 or more" : 2000000
}

# %%
toDrop = []
for i in range(2, len(housing_unit.columns)):
    if i % 2 == 0:
        toDrop.append(housing_unit.columns.tolist()[i])
housing_unit = housing_unit.drop(toDrop, axis = 1)
housing_unit.head()
# Out:
#                    Id  Estimate; Total:  Estimate; Total: - Less than $10,000  \
# Neighborhood
# Allegheny Center    1              72.0                                   0.0
# Allegheny West      2              69.0                                   4.0
# Allentown           3             538.0                                  45.0
# Arlington           4             492.0                                  12.0
# Arlington Heights   5               0.0                                   0.0
#
#                    Estimate; Total: - $10,000 to $14,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                           19.0
# Arlington                                           29.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $15,000 to $19,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                           22.0
# Arlington                                            5.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $20,000 to $24,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                           44.0
# Arlington                                           43.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $25,000 to $29,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                          100.0
# Arlington                                           27.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $30,000 to $34,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                           49.0
# Arlington                                           45.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $35,000 to $39,999  \
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                           24.0
# Arlington                                           49.0
# Arlington Heights                                    0.0
#
#                    Estimate; Total: - $40,000 to $49,999  ...  \
# Neighborhood                                              ...
# Allegheny Center                                     0.0  ...
# Allegheny West                                       0.0  ...
# Allentown                                           97.0  ...
# Arlington                                           87.0  ...
# Arlington Heights                                    0.0  ...
#
#                    Estimate; Total: - $175,000 to $199,999  \
# Neighborhood
# Allegheny Center                                      29.0
# Allegheny West                                         0.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $200,000 to $249,999  \
# Neighborhood
# Allegheny Center                                      12.0
# Allegheny West                                         4.0
# Allentown                                              0.0
# Arlington                                              2.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $250,000 to $299,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                        15.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $300,000 to $399,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                        21.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $400,000 to $499,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $500,000 to $749,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                              6.0
# Arlington                                              7.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $750,000 to $999,999  \
# Neighborhood
# Allegheny Center                                       0.0
# Allegheny West                                         0.0
# Allentown                                              0.0
# Arlington                                              0.0
# Arlington Heights                                      0.0
#
#                    Estimate; Total: - $1,000,000 to $1,499,999  \
# Neighborhood
# Allegheny Center                                           0.0
# Allegheny West                                            11.0
# Allentown                                                  0.0
# Arlington                                                  3.0
# Arlington Heights                                          0.0
#
#                    Estimate; Total: - $1,500,000 to $1,999,999  \
# Neighborhood
# Allegheny Center                                           0.0
# Allegheny West                                             0.0
# Allentown                                                  0.0
# Arlington                                                  0.0
# Arlington Heights                                          0.0
#
#                    Estimate; Total: - $2,000,000 or more
# Neighborhood
# Allegheny Center                                     0.0
# Allegheny West                                       0.0
# Allentown                                            0.0
# Arlington                                            0.0
# Arlington Heights                                    0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# We'll create a dictionary to store our average prices. The values of this dictionary will then be used as the new row to our data set containing all the average values.
#
# We can calculate the average housing unit value for each row by iterating through each row, and multiplying the number of times a certain value appears with the value itself. Then, we divide by the sample size to get our average.
# This average is added to our dictionary under the same row name as the data used to calculate it.
#
# We can also clean up our data by dropping any rows that don't have enough data (a sample size of 0), as we would be left with an indetermine value of 0/0 otherwise.
#
# Finally, we can add the values of our average price dictionary as a new column to the dataframe, and then sort by it in descending order.

# %%
avg_price = {}
rowsToDrop = []
for index, row in housing_unit.iterrows():
    if index not in avg_price:
        avg_price[index] = 0
    for value in value_dict.keys():
        avg_price[index] += row["Estimate; Total: - " + value] * value_dict[value]
    if row["Estimate; Total:"] != 0:
        avg_price[index] /= row["Estimate; Total:"]
    else:
        toDrop.append(index)
housing_unit = housing_unit.drop(rowsToDrop, axis = 0)
housing_unit.insert(1, "Average Price", avg_price)
housing_unit = housing_unit.sort_values(by="Average Price", ascending = False)

housing_unit.head()
# Out:
#                      Id  Average Price  Estimate; Total:  \
# Neighborhood
# Chateau              22  625000.000000               3.0
# Squirrel Hill North  77  517580.071174            1967.0
# Allegheny West        2  405652.173913              69.0
# Shadyside            69  366632.231405            1936.0
# Point Breeze         64  349149.722736            1623.0
#
#                      Estimate; Total: - Less than $10,000  \
# Neighborhood
# Chateau                                               0.0
# Squirrel Hill North                                  11.0
# Allegheny West                                        4.0
# Shadyside                                             0.0
# Point Breeze                                         14.0
#
#                      Estimate; Total: - $10,000 to $14,999  \
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                    0.0
# Allegheny West                                         0.0
# Shadyside                                              0.0
# Point Breeze                                           0.0
#
#                      Estimate; Total: - $15,000 to $19,999  \
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                    0.0
# Allegheny West                                         0.0
# Shadyside                                              0.0
# Point Breeze                                           0.0
#
#                      Estimate; Total: - $20,000 to $24,999  \
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                    0.0
# Allegheny West                                         0.0
# Shadyside                                             13.0
# Point Breeze                                          15.0
#
#                      Estimate; Total: - $25,000 to $29,999  \
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                    0.0
# Allegheny West                                         0.0
# Shadyside                                              0.0
# Point Breeze                                           0.0
#
#                      Estimate; Total: - $30,000 to $34,999  \
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                    8.0
# Allegheny West                                         0.0
# Shadyside                                              0.0
# Point Breeze                                           5.0
#
#                      Estimate; Total: - $35,000 to $39,999  ...  \
# Neighborhood                                                ...
# Chateau                                                0.0  ...
# Squirrel Hill North                                    0.0  ...
# Allegheny West                                         0.0  ...
# Shadyside                                              0.0  ...
# Point Breeze                                           0.0  ...
#
#                      Estimate; Total: - $175,000 to $199,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                     77.0
# Allegheny West                                           0.0
# Shadyside                                               95.0
# Point Breeze                                            80.0
#
#                      Estimate; Total: - $200,000 to $249,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                    216.0
# Allegheny West                                           4.0
# Shadyside                                              244.0
# Point Breeze                                           217.0
#
#                      Estimate; Total: - $250,000 to $299,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                    188.0
# Allegheny West                                          15.0
# Shadyside                                              268.0
# Point Breeze                                           250.0
#
#                      Estimate; Total: - $300,000 to $399,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                    279.0
# Allegheny West                                          21.0
# Shadyside                                              332.0
# Point Breeze                                           318.0
#
#                      Estimate; Total: - $400,000 to $499,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                    307.0
# Allegheny West                                           0.0
# Shadyside                                              163.0
# Point Breeze                                           246.0
#
#                      Estimate; Total: - $500,000 to $749,999  \
# Neighborhood
# Chateau                                                  3.0
# Squirrel Hill North                                    383.0
# Allegheny West                                           0.0
# Shadyside                                              243.0
# Point Breeze                                           168.0
#
#                      Estimate; Total: - $750,000 to $999,999  \
# Neighborhood
# Chateau                                                  0.0
# Squirrel Hill North                                    206.0
# Allegheny West                                           0.0
# Shadyside                                              111.0
# Point Breeze                                            71.0
#
#                      Estimate; Total: - $1,000,000 to $1,499,999  \
# Neighborhood
# Chateau                                                      0.0
# Squirrel Hill North                                         74.0
# Allegheny West                                              11.0
# Shadyside                                                   36.0
# Point Breeze                                                 8.0
#
#                      Estimate; Total: - $1,500,000 to $1,999,999  \
# Neighborhood
# Chateau                                                      0.0
# Squirrel Hill North                                         21.0
# Allegheny West                                               0.0
# Shadyside                                                   17.0
# Point Breeze                                                 4.0
#
#                      Estimate; Total: - $2,000,000 or more
# Neighborhood
# Chateau                                                0.0
# Squirrel Hill North                                   50.0
# Allegheny West                                         0.0
# Shadyside                                              0.0
# Point Breeze                                           0.0
#
# [5 rows x 29 columns]

# %%
housing_unit.plot(kind="bar", stacked = True, ylim = 0, figsize = (20, 4), title = "Average Housing Unit Value By Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Unit Value")
plt.legend("", frameon=False)
plt.show()

# %% [markdown]
# Thus, by this metric that Chateau is the best neighborhood in Pittsburgh

# %% [markdown]
# ### Mortgage Status
#
# This is the measurement which describes the amount of houses in the data set which either have or do not have a mortgage on them. Since we want the neighborhood where people are spending the most money, they should have enough money to pay the mortgage. So, we are going to be looking for which neighborhood has the lowest amount of average mortgages.
#
# We need to first get our data.

# %%
# Load and clean data
mortgage_status = pd.read_csv("mortgage-status.csv", index_col = "Neighborhood")

percent_mortgage_status = []
for index, row in mortgage_status.iterrows():
    total_mortgage = row["Estimate; Housing units without a mortgage"]
    total_houses = row["Estimate; Total:"]
    if total_houses != 0:
        percent_mortgage_status.append(100 - float(total_mortgage) / total_houses * 100)
    else:
        percent_mortgage_status.append(0)   

neighborhoods = mortgage_status.index

mortgage_status = pd.DataFrame({"Neighborhood": neighborhoods, "Average Minimum Rent": percent_mortgage_status})
average_rents = average_rents.set_index("Neighborhood")
# Out:
#                    Id  Percent Mortgage Status  Estimate; Total:  \
# Neighborhood
# Northview Heights  59               100.000000              12.0
# West End           88                91.428571              35.0
# Strip District     81                88.888889              72.0
# Crawford-Roberts   24                74.778761             226.0
# Duquesne Heights   25                74.193548             837.0
#
#                    Margin of Error; Total:  \
# Neighborhood
# Northview Heights                12.000000
# West End                         23.000000
# Strip District                   40.000000
# Crawford-Roberts                 58.591808
# Duquesne Heights                109.635761
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt:  \
# Neighborhood
# Northview Heights                                               12.0
# West End                                                        32.0
# Strip District                                                  64.0
# Crawford-Roberts                                               169.0
# Duquesne Heights                                               621.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt:  \
# Neighborhood
# Northview Heights                                          12.000000
# West End                                                   23.000000
# Strip District                                             41.000000
# Crawford-Roberts                                           48.259714
# Duquesne Heights                                          114.477072
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both:  \
# Neighborhood
# Northview Heights                                                0.0
# West End                                                         0.0
# Strip District                                                   7.0
# Crawford-Roberts                                                50.0
# Duquesne Heights                                               120.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both:  \
# Neighborhood
# Northview Heights                                          10.000000
# West End                                                   10.000000
# Strip District                                             11.000000
# Crawford-Roberts                                           29.068884
# Duquesne Heights                                           48.166378
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both: - Second mortgage only  \
# Neighborhood
# Northview Heights                                                0.0
# West End                                                         0.0
# Strip District                                                   7.0
# Crawford-Roberts                                                24.0
# Duquesne Heights                                                11.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both: - Second mortgage only  \
# Neighborhood
# Northview Heights                                          10.000000
# West End                                                   10.000000
# Strip District                                             11.000000
# Crawford-Roberts                                           20.591260
# Duquesne Heights                                           13.453624
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both: - Home equity loan only  \
# Neighborhood
# Northview Heights                                                0.0
# West End                                                         0.0
# Strip District                                                   0.0
# Crawford-Roberts                                                26.0
# Duquesne Heights                                               109.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt: - With either a second mortgage or home equity loan, but not both: - Home equity loan only  \
# Neighborhood
# Northview Heights                                          10.000000
# West End                                                   10.000000
# Strip District                                             10.000000
# Crawford-Roberts                                           22.203603
# Duquesne Heights                                           44.687806
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt: - Both second mortgage and home equity loan  \
# Neighborhood
# Northview Heights                                                0.0
# West End                                                         0.0
# Strip District                                                   0.0
# Crawford-Roberts                                                10.0
# Duquesne Heights                                                13.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt: - Both second mortgage and home equity loan  \
# Neighborhood
# Northview Heights                                          10.000000
# West End                                                   10.000000
# Strip District                                             10.000000
# Crawford-Roberts                                           17.204651
# Duquesne Heights                                           17.204651
#
#                    Estimate; Housing units with a mortgage, contract to purchase, or similar debt: - No second mortgage and no home equity loan  \
# Neighborhood
# Northview Heights                                               12.0
# West End                                                        32.0
# Strip District                                                  57.0
# Crawford-Roberts                                               109.0
# Duquesne Heights                                               488.0
#
#                    Margin of Error; Housing units with a mortgage, contract to purchase, or similar debt: - No second mortgage and no home equity loan  \
# Neighborhood
# Northview Heights                                          12.000000
# West End                                                   23.000000
# Strip District                                             41.000000
# Crawford-Roberts                                           48.877398
# Duquesne Heights                                          118.406081
#
#                    Estimate; Housing units without a mortgage  \
# Neighborhood
# Northview Heights                                         0.0
# West End                                                  3.0
# Strip District                                            8.0
# Crawford-Roberts                                         57.0
# Duquesne Heights                                        216.0
#
#                    Margin of Error; Housing units without a mortgage
# Neighborhood
# Northview Heights                                          10.000000
# West End                                                    6.000000
# Strip District                                             11.000000
# Crawford-Roberts                                           36.400549
# Duquesne Heights                                           62.681736

# %% [markdown]
# Now, we can work with the data and find the neighborhood with the lowest rate of mortgages.

# %%
mortgage_status.plot(kind="bar", stacked = True, ylim = 0, figsize = (20, 4))
plt.title = "Percent Houses with no Mortgage"
plt.xlabel("Neighborhood")
plt.ylabel("Percent Houses")
plt.legend("", frameon=False)
plt.show()
